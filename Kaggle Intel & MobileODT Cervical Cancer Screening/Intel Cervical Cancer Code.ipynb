# %% [markdown]
# # Intel & MobileODT Cervical Cancer Screening

# %% [markdown]
# **Read the input and output images through Opencv and resize them to 128x128**
#
# ** Customized CNN Architecture as below **
#
#
#
#      3x3 Conv , 64 feature maps,Activation ReLU
#             ||
#      3x3 Conv , 64 feature maps,Activation ReLU
#             ||
#         2x2 MaxPooling
#             ||
#      3x3 Conv , 128 feature maps,Activation ReLU
#             ||
#      3x3 Conv , 128 feature maps,Activation ReLU
#             ||
#      2x2 MaxPooling
#             ||
#      3x3 Conv , 256 feature maps,Activation ReLU
#             ||
#      3x3 Conv , 256 feature maps,Activation ReLU
#             ||
#      3x3 Conv , 256 feature maps,Activation ReLU
#             ||
#      2x2 MaxPooling
#             ||
#      3x3 Conv , 512 feature maps,Activation ReLU
#             ||
#      3x3 Conv , 512 feature maps,Activation ReLU
#             ||
#      2x2 MaxPooling
#             ||
#          Flatten
#             ||
#      512 Dense units, Fully Connected layer, Activation ReLU
#             ||
#      Dropout 0.5
#             ||
#      512 Dense units, Fully Connected layer, Activation ReLU
#             ||
#      Dropout 0.5
#             ||
#      Dense 3, Output layer
#
#    ** Train by 5 fold cross validation and take the average prediction of the 5 models**

# %%
_author__ = 'Santanu Pattanayak'

import numpy as np
np.random.seed(1000)

import os
import glob
import cv2
import datetime
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")

from sklearn.cross_validation import KFold
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from sklearn.metrics import log_loss
from keras import __version__ as keras_version

start_time = time.time()
print 'Starting time:',start_time

def get_im_cv2(path):
    img = cv2.imread(path)
    #resized = cv2.resize(img, (64,64), cv2.INTER_LINEAR)
    resized = cv2.resize(img, (128,128), cv2.INTER_LINEAR)
    return resized


def load_train():
    X_train = []
    X_train_id = []
    y_train = []
    start_time = time.time()

    print('Read train images')
    folders = ['Type_1', 'Type_2', 'Type_3']
    for fld in folders:
        index = folders.index(fld)
        print('Load folder {} (Index: {})'.format(fld, index))
        path = os.path.join('.', 'Downloads', 'Intel','train', fld, '*.jpg')
        files = glob.glob(path)
        
        for fl in files:
            flbase = os.path.basename(fl)
            img = get_im_cv2(fl)
            X_train.append(img)
            X_train_id.append(flbase)
            y_train.append(index)
    for fld in folders:
        index = folders.index(fld)
        print('Load folder {} (Index: {})'.format(fld, index))
        path = os.path.join('.', 'Downloads', 'Intel','Additional', fld, '*.jpg')
        files = glob.glob(path)
        
        for fl in files:
            flbase = os.path.basename(fl)
            img = get_im_cv2(fl)
            X_train.append(img)
            X_train_id.append(flbase)
            y_train.append(index)


    print('Read train data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return X_train, y_train, X_train_id


def load_test():
    path = os.path.join('.', 'Downloads','Intel','test', '*.jpg')
    files = sorted(glob.glob(path))

    X_test = []
    X_test_id = []
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl)
        X_test.append(img)
        X_test_id.append(flbase)
    path = os.path.join('.', 'Downloads','Intel','test_stg2', '*.jpg')
    files = sorted(glob.glob(path))
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl)
        X_test.append(img)
        X_test_id.append(flbase)
    


    return X_test, X_test_id


def create_submission(predictions, test_id, info):
    result1 = pd.DataFrame(predictions, columns=['Type_1', 'Type_2', 'Type_3'])
    result1.loc[:, 'image'] = pd.Series(test_id, index=result1.index)
    now = datetime.datetime.now()
    sub_file = 'submission_' + info + '_' + str(now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
    result1.to_csv(sub_file, index=False)


def read_and_normalize_train_data():
    train_data, train_target, train_id = load_train()

    print('Convert to numpy...')
    train_data = np.array(train_data, dtype=np.uint8)
    train_target = np.array(train_target, dtype=np.uint8)

    print('Reshape...')
    train_data = train_data.transpose((0, 3, 1, 2))

    print('Convert to float...')
    train_data = train_data.astype('float32')
    train_data = train_data / 255
    train_target = np_utils.to_categorical(train_target, 3)

    print('Train shape:', train_data.shape)
    print(train_data.shape[0], 'train samples')
    return train_data, train_target, train_id


def read_and_normalize_test_data():
    start_time = time.time()
    test_data, test_id = load_test()

    test_data = np.array(test_data, dtype=np.uint8)
    test_data = test_data.transpose((0, 3, 1, 2))

    test_data = test_data.astype('float32')
    test_data = test_data / 255

    print('Test shape:', test_data.shape)
    print(test_data.shape[0], 'test samples')
    print('Read and process test data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return test_data, test_id


def dict_to_list(d):
    ret = []
    for i in d.items():
        ret.append(i[1])
    return ret


def merge_several_folds_mean(data, nfolds):
    a = np.array(data[0])
    for i in range(1, nfolds):
        a += np.array(data[i])
    a /= nfolds
    return a.tolist()


def create_model():
    model = Sequential()
    
    model.add(ZeroPadding2D((1, 1), input_shape=(3,128,128), dim_ordering='th'))
    model.add(Convolution2D(64, 3, 3, activation='relu', dim_ordering='th'))
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(64, 3, 3, activation='relu', dim_ordering='th'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))

    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(128, 3, 3, activation='relu', dim_ordering='th'))
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(128, 3, 3, activation='relu', dim_ordering='th'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))
    
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(256, 3, 3, activation='relu', dim_ordering='th'))
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(256, 3, 3, activation='relu', dim_ordering='th'))
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(256, 3, 3, activation='relu', dim_ordering='th'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))
    
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(512, 3, 3, activation='relu', dim_ordering='th'))
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(512, 3, 3, activation='relu', dim_ordering='th'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))
    ### add more --------------------------------------------------------------------
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(512, 3, 3, activation='relu', dim_ordering='th'))
    model.add(ZeroPadding2D((1, 1), dim_ordering='th'))
    model.add(Convolution2D(512, 3, 3, activation='relu', dim_ordering='th'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))
    ##-------------------------------------------------------------------------------
    
    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    #model.add(Dropout(0.7)) best model so far with 0.7
    model.add(Dropout(0.5))
    model.add(Dense(512, activation='relu',name='feature_layer'))
    #model.add(Dropout(0.7)) best model so far with 0.7
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))

    sgd = SGD(lr=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='categorical_crossentropy')

    return model

def create_model2():
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(8, activation='softmax'))
    
    sgd = SGD(lr=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='categorical_crossentropy')

    return model


def get_validation_predictions(train_data, predictions_valid):
    pv = []
    for i in range(len(train_data)):
        pv.append(predictions_valid[i])
    return pv


def run_cross_validation_create_models(nfolds=10):
    # input image dimensions
    batch_size = 32
    nb_epoch = 30
    random_state = 51

    train_data, train_target, train_id = read_and_normalize_train_data()

    yfull_train = dict()
    kf = KFold(len(train_id), n_folds=nfolds, shuffle=True, random_state=random_state)
    num_fold = 0
    sum_score = 0
    models = []
    for train_index, test_index in kf:
        model = create_model()
        X_train = train_data[train_index]
        Y_train = train_target[train_index]
        X_valid = train_data[test_index]
        Y_valid = train_target[test_index]

        num_fold += 1
        print('Start KFold number {} from {}'.format(num_fold, nfolds))
        print('Split train: ', len(X_train), len(Y_train))
        print('Split valid: ', len(X_valid), len(Y_valid))

        callbacks = [
            EarlyStopping(monitor='val_loss', patience=20, verbose=0),
        ]
        model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
              shuffle=True, verbose=2, validation_data=(X_valid, Y_valid),
              callbacks=callbacks)

        predictions_valid = model.predict(X_valid.astype('float32'), batch_size=batch_size, verbose=2)
        score = log_loss(Y_valid, predictions_valid)
        print('Score log_loss: ', score)
        sum_score += score*len(test_index)

        # Store valid predictions
        for i in range(len(test_index)):
            yfull_train[test_index[i]] = predictions_valid[i]

        models.append(model)

    score = sum_score/len(train_data)
    print("Log_loss train independent avg: ", score)

    info_string = 'loss_' + str(score) + '_folds_' + str(nfolds) + '_ep_' + str(nb_epoch)
    return info_string, models


def run_cross_validation_process_test(info_string, models):
    batch_size = 32
    num_fold = 0
    yfull_test = []
    test_id = []
    nfolds = len(models)

    for i in range(nfolds):
        model = models[i]
        num_fold += 1
        print('Start KFold number {} from {}'.format(num_fold, nfolds))
        test_data, test_id = read_and_normalize_test_data()
        test_prediction = model.predict(test_data, batch_size=batch_size, verbose=2)
        yfull_test.append(test_prediction)

    test_res = merge_several_folds_mean(yfull_test, nfolds)
    info_string = 'loss_' + info_string \
                + '_folds_' + str(nfolds)
    create_submission(test_res, test_id, info_string)


if __name__ == '__main__':
    print('Keras version: {}'.format(keras_version))
    num_folds = 5
    info_string, models = run_cross_validation_create_models(num_folds)
    run_cross_validation_process_test(info_string, models)
    end_time = time.time()
    print 'end time:',start_time
    total_time = end_time - start_time
    print 'total processing time', total_time
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Using TensorFlow backend.
# Starting time: 1498071992.14
# Keras version: 2.0.1
# Read train images
# Load folder Type_1 (Index: 0)
# Load folder Type_2 (Index: 1)
# Load folder Type_3 (Index: 2)
# Load folder Type_1 (Index: 0)
# Load folder Type_2 (Index: 1)
# Load folder Type_3 (Index: 2)
# Read train data time: 1103.65 seconds
# Convert to numpy...
# Reshape...
# Convert to float...
# ('Train shape:', (8209, 3, 128, 128))
# (8209, 'train samples')
# Start KFold number 1 from 5
# ('Split train: ', 6567, 6567)
# ('Split valid: ', 1642, 1642)
# Train on 6567 samples, validate on 1642 samples
# Epoch 1/30
# 102s - loss: 1.0103 - val_loss: 1.0040
# Epoch 2/30
# 98s - loss: 1.0053 - val_loss: 1.0035
# Epoch 3/30
# 98s - loss: 1.0035 - val_loss: 1.0113
# Epoch 4/30
# 98s - loss: 1.0048 - val_loss: 1.0053
# Epoch 5/30
# 98s - loss: 1.0039 - val_loss: 1.0040
# Epoch 6/30
# 98s - loss: 1.0037 - val_loss: 1.0052
# Epoch 7/30
# 98s - loss: 1.0035 - val_loss: 1.0034
# Epoch 8/30
# 98s - loss: 1.0029 - val_loss: 1.0035
# Epoch 9/30
# 98s - loss: 1.0029 - val_loss: 1.0035
# Epoch 10/30
# 98s - loss: 1.0026 - val_loss: 1.0054
# Epoch 11/30
# 98s - loss: 1.0032 - val_loss: 1.0055
# Epoch 12/30
# 98s - loss: 1.0026 - val_loss: 1.0044
# Epoch 13/30
# 98s - loss: 1.0030 - val_loss: 1.0035
# Epoch 14/30
# 98s - loss: 1.0028 - val_loss: 1.0037
# Epoch 15/30
# 98s - loss: 1.0034 - val_loss: 1.0044
# Epoch 16/30
# 98s - loss: 1.0028 - val_loss: 1.0036
# Epoch 17/30
# 98s - loss: 1.0029 - val_loss: 1.0041
# Epoch 18/30
# 98s - loss: 1.0020 - val_loss: 1.0058
# Epoch 19/30
# 98s - loss: 1.0030 - val_loss: 1.0037
# Epoch 20/30
# 98s - loss: 1.0027 - val_loss: 1.0047
# Epoch 21/30
# 98s - loss: 1.0029 - val_loss: 1.0039
# Epoch 22/30
# 98s - loss: 1.0029 - val_loss: 1.0036
# Epoch 23/30
# 98s - loss: 1.0023 - val_loss: 1.0042
# Epoch 24/30
# 98s - loss: 1.0023 - val_loss: 1.0043
# Epoch 25/30
# 98s - loss: 1.0027 - val_loss: 1.0034
# Epoch 26/30
# 98s - loss: 1.0029 - val_loss: 1.0039
# Epoch 27/30
# 98s - loss: 1.0027 - val_loss: 1.0039
# Epoch 28/30
# 98s - loss: 1.0021 - val_loss: 1.0034
# Epoch 29/30
# 98s - loss: 1.0025 - val_loss: 1.0038
# Epoch 30/30
# 98s - loss: 1.0022 - val_loss: 1.0039
# ('Score log_loss: ', 1.0039488844909272)
# Start KFold number 2 from 5
# ('Split train: ', 6567, 6567)
# ('Split valid: ', 1642, 1642)
# Train on 6567 samples, validate on 1642 samples
# Epoch 1/30
# 99s - loss: 1.0076 - val_loss: 1.0124
# Epoch 2/30
# 99s - loss: 1.0031 - val_loss: 1.0119
# Epoch 3/30
# 99s - loss: 1.0009 - val_loss: 1.0168
# Epoch 4/30
# 99s - loss: 1.0019 - val_loss: 1.0127
# Epoch 5/30
# 99s - loss: 1.0005 - val_loss: 1.0132
# Epoch 6/30
# 99s - loss: 1.0010 - val_loss: 1.0154
# Epoch 7/30
# 99s - loss: 1.0017 - val_loss: 1.0154
# Epoch 8/30
# 99s - loss: 1.0011 - val_loss: 1.0127
# Epoch 9/30
# 99s - loss: 1.0011 - val_loss: 1.0118
# Epoch 10/30
# 99s - loss: 1.0015 - val_loss: 1.0135
# Epoch 11/30
# 99s - loss: 1.0000 - val_loss: 1.0188
# Epoch 12/30
# 99s - loss: 1.0012 - val_loss: 1.0116
# Epoch 13/30
# 99s - loss: 1.0011 - val_loss: 1.0125
# Epoch 14/30
# 99s - loss: 1.0005 - val_loss: 1.0130
# Epoch 15/30
# 99s - loss: 1.0004 - val_loss: 1.0154
# Epoch 16/30
# 99s - loss: 1.0003 - val_loss: 1.0129
# Epoch 17/30
# 99s - loss: 1.0004 - val_loss: 1.0126
# Epoch 18/30
# 99s - loss: 1.0001 - val_loss: 1.0122
# Epoch 19/30
# 99s - loss: 1.0004 - val_loss: 1.0127
# Epoch 20/30
# 99s - loss: 1.0000 - val_loss: 1.0147
# Epoch 21/30
# 99s - loss: 1.0002 - val_loss: 1.0148
# Epoch 22/30
# 99s - loss: 1.0006 - val_loss: 1.0125
# Epoch 23/30
# 99s - loss: 1.0001 - val_loss: 1.0124
# Epoch 24/30
# 99s - loss: 1.0001 - val_loss: 1.0126
# Epoch 25/30
# 99s - loss: 1.0009 - val_loss: 1.0118
# Epoch 26/30
# 99s - loss: 1.0004 - val_loss: 1.0125
# Epoch 27/30
# 99s - loss: 0.9998 - val_loss: 1.0139
# Epoch 28/30
# 99s - loss: 1.0005 - val_loss: 1.0119
# Epoch 29/30
# 99s - loss: 1.0001 - val_loss: 1.0129
# Epoch 30/30
# 99s - loss: 1.0000 - val_loss: 1.0121
# ('Score log_loss: ', 1.0120798766830807)
# Start KFold number 3 from 5
# ('Split train: ', 6567, 6567)
# ('Split valid: ', 1642, 1642)
# Train on 6567 samples, validate on 1642 samples
# Epoch 1/30
# 98s - loss: 1.0097 - val_loss: 1.0095
# Epoch 2/30
# 98s - loss: 1.0042 - val_loss: 1.0074
# Epoch 3/30
# 98s - loss: 1.0029 - val_loss: 1.0075
# Epoch 4/30
# 98s - loss: 1.0026 - val_loss: 1.0082
# Epoch 5/30
# 98s - loss: 1.0019 - val_loss: 1.0084
# Epoch 6/30
# 98s - loss: 1.0022 - val_loss: 1.0077
# Epoch 7/30
# 98s - loss: 1.0023 - val_loss: 1.0095
# Epoch 8/30
# 98s - loss: 1.0015 - val_loss: 1.0079
# Epoch 9/30
# 98s - loss: 1.0014 - val_loss: 1.0079
# Epoch 10/30
# 98s - loss: 1.0017 - val_loss: 1.0076
# Epoch 11/30
# 98s - loss: 1.0020 - val_loss: 1.0089
# Epoch 12/30
# 98s - loss: 1.0019 - val_loss: 1.0077
# Epoch 13/30
# 98s - loss: 1.0018 - val_loss: 1.0084
# Epoch 14/30
# 98s - loss: 1.0021 - val_loss: 1.0075
# Epoch 15/30
# 98s - loss: 1.0018 - val_loss: 1.0080
# Epoch 16/30
# 98s - loss: 1.0014 - val_loss: 1.0084
# Epoch 17/30
# 98s - loss: 1.0020 - val_loss: 1.0088
# Epoch 18/30
# 98s - loss: 1.0012 - val_loss: 1.0082
# Epoch 19/30
# 98s - loss: 1.0018 - val_loss: 1.0087
# Epoch 20/30
# 98s - loss: 1.0010 - val_loss: 1.0075
# Epoch 21/30
# 98s - loss: 1.0007 - val_loss: 1.0075
# Epoch 22/30
# 98s - loss: 1.0017 - val_loss: 1.0076
# Epoch 23/30
# 98s - loss: 1.0015 - val_loss: 1.0077
# ('Score log_loss: ', 1.0076874881147904)
# Start KFold number 4 from 5
# ('Split train: ', 6567, 6567)
# ('Split valid: ', 1642, 1642)
# Train on 6567 samples, validate on 1642 samples
# Epoch 1/30
# 99s - loss: 1.0165 - val_loss: 0.9850
# Epoch 2/30
# 99s - loss: 1.0107 - val_loss: 0.9787
# Epoch 3/30
# 99s - loss: 1.0104 - val_loss: 0.9875
# Epoch 4/30
# 99s - loss: 1.0109 - val_loss: 0.9776
# Epoch 5/30
# 99s - loss: 1.0089 - val_loss: 0.9853
# Epoch 6/30
# 99s - loss: 1.0106 - val_loss: 0.9773
# Epoch 7/30
# 99s - loss: 1.0091 - val_loss: 0.9822
# Epoch 8/30
# 99s - loss: 1.0095 - val_loss: 0.9786
# Epoch 9/30
# 99s - loss: 1.0087 - val_loss: 0.9799
# Epoch 10/30
# 99s - loss: 1.0099 - val_loss: 0.9790
# Epoch 11/30
# 99s - loss: 1.0095 - val_loss: 0.9775
# Epoch 12/30
# 99s - loss: 1.0097 - val_loss: 0.9791
# Epoch 13/30
# 99s - loss: 1.0093 - val_loss: 0.9804
# Epoch 14/30
# 99s - loss: 1.0093 - val_loss: 0.9789
# Epoch 15/30
# 99s - loss: 1.0089 - val_loss: 0.9832
# Epoch 16/30
# 99s - loss: 1.0097 - val_loss: 0.9786
# Epoch 17/30
# 99s - loss: 1.0091 - val_loss: 0.9795
# Epoch 18/30
# 99s - loss: 1.0086 - val_loss: 0.9808
# Epoch 19/30
# 99s - loss: 1.0088 - val_loss: 0.9787
# Epoch 20/30
# 99s - loss: 1.0086 - val_loss: 0.9786
# Epoch 21/30
# 99s - loss: 1.0085 - val_loss: 0.9852
# Epoch 22/30
# 99s - loss: 1.0088 - val_loss: 0.9827
# Epoch 23/30
# 99s - loss: 1.0085 - val_loss: 0.9792
# Epoch 24/30
# 99s - loss: 1.0087 - val_loss: 0.9806
# Epoch 25/30
# 99s - loss: 1.0087 - val_loss: 0.9794
# Epoch 26/30
# 99s - loss: 1.0083 - val_loss: 0.9794
# Epoch 27/30
# 99s - loss: 1.0089 - val_loss: 0.9797
# ('Score log_loss: ', 0.97966484803520371)
# Start KFold number 5 from 5
# ('Split train: ', 6568, 6568)
# ('Split valid: ', 1641, 1641)
# Train on 6568 samples, validate on 1641 samples
# Epoch 1/30
# 100s - loss: 1.0091 - val_loss: 1.0102
# Epoch 2/30
# 98s - loss: 1.0034 - val_loss: 1.0088
# Epoch 3/30
# 98s - loss: 1.0024 - val_loss: 1.0086
# Epoch 4/30
# 98s - loss: 1.0013 - val_loss: 1.0091
# Epoch 5/30
# 98s - loss: 1.0036 - val_loss: 1.0088
# Epoch 6/30
# 98s - loss: 1.0025 - val_loss: 1.0087
# Epoch 7/30
# 98s - loss: 1.0017 - val_loss: 1.0087
# Epoch 8/30
# 98s - loss: 1.0015 - val_loss: 1.0086
# Epoch 9/30
# 98s - loss: 1.0021 - val_loss: 1.0088
# Epoch 10/30
# 98s - loss: 1.0011 - val_loss: 1.0117
# Epoch 11/30
# 98s - loss: 1.0027 - val_loss: 1.0094
# Epoch 12/30
# 98s - loss: 1.0018 - val_loss: 1.0083
# Epoch 13/30
# 98s - loss: 1.0005 - val_loss: 1.0093
# Epoch 14/30
# 98s - loss: 1.0011 - val_loss: 1.0085
# Epoch 15/30
# 98s - loss: 1.0011 - val_loss: 1.0091
# Epoch 16/30
# 98s - loss: 1.0016 - val_loss: 1.0088
# Epoch 17/30
# 98s - loss: 1.0016 - val_loss: 1.0098
# Epoch 18/30
# 98s - loss: 1.0014 - val_loss: 1.0095
# Epoch 19/30
# 98s - loss: 1.0015 - val_loss: 1.0092
# Epoch 20/30
# 98s - loss: 1.0011 - val_loss: 1.0085
# Epoch 21/30
# 98s - loss: 1.0015 - val_loss: 1.0093
# Epoch 22/30
# 98s - loss: 1.0014 - val_loss: 1.0087
# Epoch 23/30
# 98s - loss: 1.0014 - val_loss: 1.0097
# Epoch 24/30
# 98s - loss: 1.0010 - val_loss: 1.0094
# Epoch 25/30
# 98s - loss: 1.0011 - val_loss: 1.0090
# Epoch 26/30
# 98s - loss: 1.0009 - val_loss: 1.0092
# Epoch 27/30
# 98s - loss: 1.0011 - val_loss: 1.0085
# Epoch 28/30
# 98s - loss: 1.0007 - val_loss: 1.0100
# Epoch 29/30
# 98s - loss: 1.0010 - val_loss: 1.0096
# Epoch 30/30
# 98s - loss: 1.0011 - val_loss: 1.0092
# ('Score log_loss: ', 1.009234034165168)
# ('Log_loss train independent avg: ', 1.0025222087795167)
# Start KFold number 1 from 5
# ('Test shape:', (4018, 3, 128, 128))
# (4018, 'test samples')
# Read and process test data time: 400.25 seconds
# Start KFold number 2 from 5
# ('Test shape:', (4018, 3, 128, 128))
# (4018, 'test samples')
# Read and process test data time: 397.57 seconds
# Start KFold number 3 from 5
# ('Test shape:', (4018, 3, 128, 128))
# (4018, 'test samples')
# Read and process test data time: 399.43 seconds
# Start KFold number 4 from 5
# ('Test shape:', (4018, 3, 128, 128))
# (4018, 'test samples')
# Read and process test data time: 395.8 seconds
# Start KFold number 5 from 5
# ('Test shape:', (4018, 3, 128, 128))
# (4018, 'test samples')
# Read and process test data time: 396.51 seconds
# end time: 1498071992.14
# total processing time 17075.776536

# %% [markdown]
# ** Generate the prediction for the test data set **

# %%
def merge_several_folds_mean(data, nfolds):
    a = np.array(data[0])
    for i in range(1, nfolds):
        a += np.array(data[i])
    a /= nfolds
    return a.tolist()

def run_cross_validation_process_test(info_string, models):
    batch_size = 32
    num_fold = 0
    yfull_test = []
    test_id = []
    nfolds = len(models)

    for i in range(nfolds):
        model = models[i]
        num_fold += 1
        print('Start KFold number {} from {}'.format(num_fold, nfolds))
        test_data, test_id = read_and_normalize_test_data()
        test_prediction = model.predict(test_data, batch_size=batch_size, verbose=2)
        yfull_test.append(test_prediction)

    test_res = merge_several_folds_mean(yfull_test, nfolds)
    info_string = 'loss_' + info_string \
                + '_folds_' + str(nfolds)
    create_submission(test_res, test_id, info_string)
    
    
def read_and_normalize_test_data():
    start_time = time.time()
    test_data, test_id = load_test()

    test_data = np.array(test_data, dtype=np.uint8)
    test_data = test_data.transpose((0, 3, 1, 2))

    test_data = test_data.astype('float32')
    test_data = test_data / 255

    print('Test shape:', test_data.shape)
    print(test_data.shape[0], 'test samples')
    print('Read and process test data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return test_data, test_id

def load_test():
    path = os.path.join('.', 'Downloads', 'test', '*.jpg')
    files = sorted(glob.glob(path))

    X_test = []
    X_test_id = []
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl)
        X_test.append(img)
        X_test_id.append(flbase)
    path = os.path.join('.', 'Downloads', 'test_stg22', '*.jpg')
    files = sorted(glob.glob(path))
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl)
        X_test.append(img)
        X_test_id.append(flbase)
    return X_test, X_test_id

info_string = ''
run_cross_validation_process_test(info_string, models)
